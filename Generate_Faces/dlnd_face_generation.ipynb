# %% [markdown]
# # Face Generation
#
# In this project, you'll define and train a DCGAN on a dataset of faces. Your goal is to get a generator network to generate *new* images of faces that look as realistic as possible!
#
# The project will be broken down into a series of tasks from **loading in data to defining and training adversarial networks**. At the end of the notebook, you'll be able to visualize the results of your trained Generator to see how it performs; your generated samples should look like fairly realistic faces with small amounts of noise.
#
# ### Get the Data
#
# You'll be using the [CelebFaces Attributes Dataset (CelebA)](http://mmlab.ie.cuhk.edu.hk/projects/CelebA.html) to train your adversarial networks.
#
# This dataset is more complex than the number datasets (like MNIST or SVHN) you've been working with, and so, you should prepare to define deeper networks and train them for a longer time to get good results. It is suggested that you utilize a GPU for training.
#
# ### Pre-processed Data
#
# Since the project's main focus is on building the GANs, we've done *some* of the pre-processing for you. Each of the CelebA images has been cropped to remove parts of the image that don't include a face, then resized down to 64x64x3 NumPy images. Some sample data is show below.
#
# <img src='assets/processed_face_data.png' width=60% />
#
# > If you are working locally, you can download this data [by clicking here](https://s3.amazonaws.com/video.udacity-data.com/topher/2018/November/5be7eb6f_processed-celeba-small/processed-celeba-small.zip)
#
# This is a zip file that you'll need to extract in the home directory of this notebook for further loading and processing. After extracting the data, you should be left with a directory of data `processed_celeba_small/`

# %%
# can comment out after executing
#!unzip processed_celeba_small.zip

# %%
data_dir = 'processed_celeba_small/'

"""
DON'T MODIFY ANYTHING IN THIS CELL
"""
import pickle as pkl
import matplotlib.pyplot as plt
import numpy as np
import problem_unittests as tests
#import helper

# %matplotlib inline

# %% [markdown]
# ## Visualize the CelebA Data
#
# The [CelebA](http://mmlab.ie.cuhk.edu.hk/projects/CelebA.html) dataset contains over 200,000 celebrity images with annotations. Since you're going to be generating faces, you won't need the annotations, you'll only need the images. Note that these are color images with [3 color channels (RGB)](https://en.wikipedia.org/wiki/Channel_(digital_image)#RGB_Images) each.
#
# ### Pre-process and Load the Data
#
# Since the project's main focus is on building the GANs, we've done *some* of the pre-processing for you. Each of the CelebA images has been cropped to remove parts of the image that don't include a face, then resized down to 64x64x3 NumPy images. This *pre-processed* dataset is a smaller subset of the very large CelebA data.
#
# > There are a few other steps that you'll need to **transform** this data and create a **DataLoader**.
#
# #### Exercise: Complete the following `get_dataloader` function, such that it satisfies these requirements:
#
# * Your images should be square, Tensor images of size `image_size x image_size` in the x and y dimension.
# * Your function should return a DataLoader that shuffles and batches these Tensor images.
#
# #### ImageFolder
#
# To create a dataset given a directory of images, it's recommended that you use PyTorch's [ImageFolder](https://pytorch.org/docs/stable/torchvision/datasets.html#imagefolder) wrapper, with a root directory `processed_celeba_small/` and data transformation passed in.

# %%
# necessary imports
import torch
from torchvision import datasets
from torchvision import transforms

# %%
def get_dataloader(batch_size, image_size, data_dir='processed_celeba_small/'):
    """
    Batch the neural network data using DataLoader
    :param batch_size: The size of each batch; the number of images in a batch
    :param img_size: The square size of the image data (x, y)
    :param data_dir: Directory where image data is located
    :return: DataLoader with batched data
    """
    
    # TODO: Implement function and return a dataloader
    num_workers = 0

    data_transforms=transforms.Compose([transforms.Resize(image_size), transforms.ToTensor()])  #transforms.Normalize(mean=[0.485, 0.456, 0.406],std=[0.229, 0.224, 0.225])

    data_data=datasets.ImageFolder(data_dir, transform=data_transforms)

    DataLoader=torch.utils.data.DataLoader(data_data, batch_size, shuffle=True, num_workers=num_workers)
      
    return DataLoader

# %% [markdown]
# ## Create a DataLoader
#
# #### Exercise: Create a DataLoader `celeba_train_loader` with appropriate hyperparameters.
#
# Call the above function and create a dataloader to view images.
# * You can decide on any reasonable `batch_size` parameter
# * Your `image_size` **must be** `32`. Resizing the data to a smaller size will make for faster training, while still creating convincing images of faces!

# %%
# Define function hyperparameters
batch_size = 128
img_size = 32

"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
# Call your function and get a dataloader
celeba_train_loader = get_dataloader(batch_size, img_size)

# %% [markdown]
# Next, you can view some images! You should seen square images of somewhat-centered faces.
#
# Note: You'll need to convert the Tensor images into a NumPy type and transpose the dimensions to correctly display an image, suggested `imshow` code is below, but it may not be perfect.

# %%
# helper display function
def imshow(img):
    npimg = img.numpy()
    plt.imshow(np.transpose(npimg, (1, 2, 0)))

"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
# obtain one batch of training images
dataiter = iter(celeba_train_loader)
images, _ = dataiter.next() # _ for no labels

# plot the images in the batch, along with the corresponding labels
fig = plt.figure(figsize=(20, 4))
plot_size=20
for idx in np.arange(plot_size):
    ax = fig.add_subplot(2, plot_size/2, idx+1, xticks=[], yticks=[])
    imshow(images[idx])

# %% [markdown]
# #### Exercise: Pre-process your image data and scale it to a pixel range of -1 to 1
#
# You need to do a bit of pre-processing; you know that the output of a `tanh` activated generator will contain pixel values in a range from -1 to 1, and so, we need to rescale our training images to a range of -1 to 1. (Right now, they are in a range from 0-1.)

# %%
# TODO: Complete the scale function
def scale(x, feature_range=(-1, 1)):
    ''' Scale takes in an image x and returns that image, scaled
       with a feature_range of pixel values from -1 to 1. 
       This function assumes that the input x is already scaled from 0-1.'''
    # assume x is scaled to (0, 1)
    # scale to feature_range and return scaled x
    min,max=feature_range
    x = x * (max - min) + min
   
    return x

# %%
"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
# check scaled range
# should be close to -1 to 1
img = images[0]
scaled_img = scale(img)

print('Min: ', scaled_img.min())
print('Max: ', scaled_img.max())
# Out:
# Min:  tensor(-0.9843)
# Max:  tensor(0.9451)

# %% [markdown]
# ---
# # Define the Model
#
# A GAN is comprised of two adversarial networks, a discriminator and a generator.
#
# ## Discriminator
#
# Your first task will be to define the discriminator. This is a convolutional classifier like you've built before, only without any maxpooling layers. To deal with this complex data, it's suggested you use a deep network with **normalization**. You are also allowed to create any helper functions that may be useful.
#
# #### Exercise: Complete the Discriminator class
# * The inputs to the discriminator are 32x32x3 tensor images
# * The output should be a single value that will indicate whether a given image is real or fake

# %%
import torch.nn as nn
import torch.nn.functional as F

#helper conv function
def conv(in_channels, out_channels, kernel_size, stride=2, padding=1, batch_norm=True):
    # Create conv layers with optional batch normalization
    
    layers=[]
    conv_layer=nn.Conv2d(in_channels, out_channels, kernel_size, stride, padding, bias=False)
    
    # Append conv layers
    layers.append(conv_layer)
    
    if batch_norm:
        layers.append(nn.BatchNorm2d(out_channels))
        
    # using sequential container
    return nn.Sequential(*layers)

# %%
class Discriminator(nn.Module):

    def __init__(self, conv_dim):
        """
        Initialize the Discriminator Module
        :param conv_dim: The depth of the first convolutional layer
        """
        super(Discriminator, self).__init__()

        # complete init function
        self.conv_dim=conv_dim
        # 32x32 input
        self.conv1=conv(3, conv_dim, 4, batch_norm=False)
        # 16x16 out
        self.conv2=conv(conv_dim, conv_dim*2, 4)
        # 8x8 out
        self.conv3=conv(conv_dim*2, conv_dim*4, 4)
        # 4x4 out
        
        #flatten
        self.fc=nn.Linear(conv_dim*4*4*4,1)

    def forward(self, x):
        """
        Forward propagation of the neural network
        :param x: The input to the neural network     
        :return: Discriminator logits; the output of the neural network
        """
        # define feedforward behavior
        out=F.leaky_relu(self.conv1(x), 0.2)
        out=F.leaky_relu(self.conv2(out), 0.2)
        out=F.leaky_relu(self.conv3(out), 0.2)
        
        #flatten
        out=out.view(-1, self.conv_dim*4*4*4)
        
        #final output layer
        out=self.fc(out)
        return out


"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
tests.test_discriminator(Discriminator)
# Out:
# Tests Passed

# %% [markdown]
# ## Generator
#
# The generator should upsample an input and generate a *new* image of the same size as our training data `32x32x3`. This should be mostly transpose convolutional layers with normalization applied to the outputs.
#
# #### Exercise: Complete the Generator class
# * The inputs to the generator are vectors of some length `z_size`
# * The output should be a image of shape `32x32x3`

# %%
#helper deconv function
def deconv(in_channels, out_channels, kernel_size, stride=2, padding=1, batch_norm=True):
    # Create conv layers with optional batch normalization
    
    layers=[]
    transpose_conv_layer=nn.ConvTranspose2d(in_channels, out_channels, kernel_size, stride, padding, bias=False)
    
    # Append conv layers
    layers.append(transpose_conv_layer)
    
    if batch_norm:
        layers.append(nn.BatchNorm2d(out_channels))
        
    # using sequential container
    return nn.Sequential(*layers)

# %%
class Generator(nn.Module):
    
    def __init__(self, z_size, conv_dim):
        """
        Initialize the Generator Module
        :param z_size: The length of the input latent vector, z
        :param conv_dim: The depth of the inputs to the *last* transpose convolutional layer
        """
        super(Generator, self).__init__()

        # complete init function
        self.conv_dim=conv_dim
        
        #first fully connected layer
        self.fc=nn.Linear(z_size, conv_dim*4*4*4)
        
        # transpose conv layers
        self.t_conv1=deconv(conv_dim*4, conv_dim*2, 4)
        self.t_conv2=deconv(conv_dim*2, conv_dim, 4)
        self.t_conv3=deconv(conv_dim, 3, 4, batch_norm=False)
         

    def forward(self, x):
        """
        Forward propagation of the neural network
        :param x: The input to the neural network     
        :return: A 32x32x3 Tensor image as output
        """
        # fully-connected + reshape
        out=self.fc(x)
        out=out.view(-1, self.conv_dim*4, 4, 4)
        
        # hidden transpose conv layers + relu
        out=F.relu(self.t_conv1(out))
        out=F.relu(self.t_conv2(out))
        
        out=self.t_conv3(out)
        out=F.tanh(out)
           
        return out

"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
tests.test_generator(Generator)
# Out:
# C:\Users\Sertan\Anaconda3\envs\dog\lib\site-packages\torch\nn\functional.py:995: UserWarning: nn.functional.tanh is deprecated. Use torch.tanh instead.
#   warnings.warn("nn.functional.tanh is deprecated. Use torch.tanh instead.")
# Tests Passed

# %% [markdown]
# ## Initialize the weights of your networks
#
# To help your models converge, you should initialize the weights of the convolutional and linear layers in your model. From reading the [original DCGAN paper](https://arxiv.org/pdf/1511.06434.pdf), they say:
# > All weights were initialized from a zero-centered Normal distribution with standard deviation 0.02.
#
# So, your next task will be to define a weight initialization function that does just this!
#
# You can refer back to the lesson on weight initialization or even consult existing model code, such as that from [the `networks.py` file in CycleGAN Github repository](https://github.com/junyanz/pytorch-CycleGAN-and-pix2pix/blob/master/models/networks.py) to help you complete this function.
#
# #### Exercise: Complete the weight initialization function
#
# * This should initialize only **convolutional** and **linear** layers
# * Initialize the weights to a normal distribution, centered around 0, with a standard deviation of 0.02.
# * The bias terms, if they exist, may be left alone or set to 0.

# %%
from torch.nn import init
def weights_init_normal(m):
    """
    Applies initial weights to certain layers in a model .
    The weights are taken from a normal distribution 
    with mean = 0, std dev = 0.02.
    :param m: A module or layer in a network    
    """
    # classname will be something like:
    # `Conv`, `BatchNorm2d`, `Linear`, etc.
    classname = m.__class__.__name__
    if classname.find('Conv') != -1:
        torch.nn.init.normal_(m.weight.data, 0.0, 0.02)
    elif classname.find('BatchNorm2d') != -1:
        torch.nn.init.normal_(m.weight.data, 1.0, 0.02)
        torch.nn.init.constant_(m.bias.data, 0.0)

# %% [markdown]
# ## Build complete network
#
# Define your models' hyperparameters and instantiate the discriminator and generator from the classes defined above. Make sure you've passed in the correct input arguments.

# %%
"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
def build_network(d_conv_dim, g_conv_dim, z_size):
    # define discriminator and generator
    D = Discriminator(d_conv_dim)
    G = Generator(z_size=z_size, conv_dim=g_conv_dim)

    # initialize model weights
    D.apply(weights_init_normal)
    G.apply(weights_init_normal)

    print(D)
    print()
    print(G)
    
    return D, G

# %% [markdown]
# #### Exercise: Define model hyperparameters

# %%
# Define model hyperparams
d_conv_dim = 32
g_conv_dim = 32
z_size = 100

"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
D, G = build_network(d_conv_dim, g_conv_dim, z_size)
# Out:
# Discriminator(
#   (conv1): Sequential(
#     (0): Conv2d(3, 32, kernel_size=(4, 4), stride=(2, 2), padding=(1, 1), bias=False)
#   )
#   (conv2): Sequential(
#     (0): Conv2d(32, 64, kernel_size=(4, 4), stride=(2, 2), padding=(1, 1), bias=False)
#     (1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   )
#   (conv3): Sequential(
#     (0): Conv2d(64, 128, kernel_size=(4, 4), stride=(2, 2), padding=(1, 1), bias=False)
#     (1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   )
#   (fc): Linear(in_features=2048, out_features=1, bias=True)
# )
#
# Generator(
#   (fc): Linear(in_features=100, out_features=2048, bias=True)
#   (t_conv1): Sequential(
#     (0): ConvTranspose2d(128, 64, kernel_size=(4, 4), stride=(2, 2), padding=(1, 1), bias=False)
#     (1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   )
#   (t_conv2): Sequential(
#     (0): ConvTranspose2d(64, 32, kernel_size=(4, 4), stride=(2, 2), padding=(1, 1), bias=False)
#     (1): BatchNorm2d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   )
#   (t_conv3): Sequential(
#     (0): ConvTranspose2d(32, 3, kernel_size=(4, 4), stride=(2, 2), padding=(1, 1), bias=False)
#   )
# )

# %% [markdown]
# ### Training on GPU
#
# Check if you can train on GPU. Here, we'll set this as a boolean variable `train_on_gpu`. Later, you'll be responsible for making sure that
# >* Models,
# * Model inputs, and
# * Loss function arguments
#
# Are moved to GPU, where appropriate.

# %%
"""
DON'T MODIFY ANYTHING IN THIS CELL
"""
import torch

# Check for a GPU
train_on_gpu = torch.cuda.is_available()
if not train_on_gpu:
    print('No GPU found. Please use a GPU to train your neural network.')
else:
    print('Training on GPU!')
# Out:
# Training on GPU!

# %% [markdown]
# ---
# ## Discriminator and Generator Losses
#
# Now we need to calculate the losses for both types of adversarial networks.
#
# ### Discriminator Losses
#
# > * For the discriminator, the total loss is the sum of the losses for real and fake images, `d_loss = d_real_loss + d_fake_loss`.
# * Remember that we want the discriminator to output 1 for real images and 0 for fake images, so we need to set up the losses to reflect that.
#
#
# ### Generator Loss
#
# The generator loss will look similar only with flipped labels. The generator's goal is to get the discriminator to *think* its generated images are *real*.
#
# #### Exercise: Complete real and fake loss functions
#
# **You may choose to use either cross entropy or a least squares error loss to complete the following `real_loss` and `fake_loss` functions.**

# %%
def real_loss(D_out):
    '''Calculates how close discriminator outputs are to being real.
       param, D_out: discriminator logits
       return: real loss'''
    loss = torch.mean((D_out-1)**2)
    return loss

def fake_loss(D_out):
    '''Calculates how close discriminator outputs are to being fake.
       param, D_out: discriminator logits
       return: fake loss'''
    loss = torch.mean(D_out**2)
    return loss

# %% [markdown]
# ## Optimizers
#
# #### Exercise: Define optimizers for your Discriminator (D) and Generator (G)
#
# Define optimizers for your models with appropriate hyperparameters.

# %%
import torch.optim as optim

# params
lr = 0.0002
beta1=0.5
beta2=0.999 # default value

# Create optimizers for the discriminator D and generator G
d_optimizer = optim.Adam(D.parameters(), lr, [beta1, beta2])
g_optimizer = optim.Adam(G.parameters(), lr, [beta1, beta2])

# %% [markdown]
# ---
# ## Training
#
# Training will involve alternating between training the discriminator and the generator. You'll use your functions `real_loss` and `fake_loss` to help you calculate the discriminator losses.
#
# * You should train the discriminator by alternating on real and fake images
# * Then the generator, which tries to trick the discriminator and should have an opposing loss function
#
#
# #### Saving Samples
#
# You've been given some code to print out some loss statistics and save some generated "fake" samples.

# %% [markdown]
# #### Exercise: Complete the training function
#
# Keep in mind that, if you've moved your models to GPU, you'll also have to move any model inputs to GPU.

# %%
import pickle as pkl
def train(D, G, n_epochs, print_every=50):
    '''Trains adversarial networks for some number of epochs
       param, D: the discriminator network
       param, G: the generator network
       param, n_epochs: number of epochs to train for
       param, print_every: when to print and record the models' losses
       return: D and G losses'''
    
    # move models to GPU
    if train_on_gpu:
        D.cuda()
        G.cuda()

    # keep track of loss and generated, "fake" samples
    samples = []
    losses = []

    # Get some fixed data for sampling. These are images that are held
    # constant throughout training, and allow us to inspect the model's performance
    sample_size=16
    fixed_z = np.random.uniform(-1, 1, size=(sample_size, z_size))
    fixed_z = torch.from_numpy(fixed_z).float()
    # move z to GPU if available
    if train_on_gpu:
        fixed_z = fixed_z.cuda()

    # epoch training loop
    for epoch in range(n_epochs):

        # batch training loop
        for batch_i, (real_images, _) in enumerate(celeba_train_loader):

            batch_size = real_images.size(0)
            real_images = scale(real_images)

            # ===============================================
            #         YOUR CODE HERE: TRAIN THE NETWORKS
            # ===============================================
            
            # 1. Train the discriminator on real and fake images
            #d_loss = 

            d_optimizer.zero_grad()
        
            # 1. Train with real images

            # Compute the discriminator losses on real images 
            if train_on_gpu:
                real_images = real_images.cuda()

            D_real = D(real_images)
            d_real_loss = real_loss(D_real)

            # 2. Train with fake images

            # Generate fake images
            z = np.random.uniform(-1, 1, size=(batch_size, z_size))
            z = torch.from_numpy(z).float()
            # move x to GPU, if available
            if train_on_gpu:
                z = z.cuda()
            fake_images = G(z)

            # Compute the discriminator losses on fake images            
            D_fake = D(fake_images)
            d_fake_loss = fake_loss(D_fake)

            # add up loss and perform backprop
            d_loss = d_real_loss + d_fake_loss
            d_loss.backward()
            d_optimizer.step()
            
            
            
            # 2. Train the generator with an adversarial loss
            #g_loss = 
            
            g_optimizer.zero_grad()

            # 1. Train with fake images and flipped labels

            # Generate fake images
            z = np.random.uniform(-1, 1, size=(batch_size, z_size))
            z = torch.from_numpy(z).float()
            if train_on_gpu:
                z = z.cuda()
            fake_images = G(z)

            # Compute the discriminator losses on fake images 
            # using flipped labels!
            D_fake = D(fake_images)
            g_loss = real_loss(D_fake) # use real loss to flip labels

            # perform backprop
            g_loss.backward()
            g_optimizer.step()
            
            
            # ===============================================
            #              END OF YOUR CODE
            # ===============================================

            # Print some loss stats
            if batch_i % print_every == 0:
                # append discriminator loss and generator loss
                losses.append((d_loss.item(), g_loss.item()))
                # print discriminator and generator loss
                print('Epoch [{:5d}/{:5d}] | d_loss: {:6.4f} | g_loss: {:6.4f}'.format(
                        epoch+1, n_epochs, d_loss.item(), g_loss.item()))


        ## AFTER EACH EPOCH##    
        # this code assumes your generator is named G, feel free to change the name
        # generate and save sample, fake images
        G.eval() # for generating samples
        if train_on_gpu:
            fixed_z = fixed_z.cuda()
        samples_z = G(fixed_z)
        samples.append(samples_z)
        G.train() # back to training mode

    # Save training generator samples
    with open('train_samples.pkl', 'wb') as f:
        pkl.dump(samples, f)
    
    # finally return losses
    return losses

# %% [markdown]
# Set your number of training epochs and train your GAN!

# %%
# set number of epochs 
n_epochs = 50


"""
DON'T MODIFY ANYTHING IN THIS CELL
"""
# call training function
losses = train(D, G, n_epochs=n_epochs)
# Out:
# Epoch [    1/   50] | d_loss: 2.2581 | g_loss: 0.5028
# Epoch [    1/   50] | d_loss: 0.1599 | g_loss: 0.7502
# Epoch [    1/   50] | d_loss: 0.1897 | g_loss: 1.2329
# Epoch [    1/   50] | d_loss: 0.0984 | g_loss: 1.1258
# Epoch [    1/   50] | d_loss: 0.1508 | g_loss: 0.6620
# Epoch [    1/   50] | d_loss: 0.1183 | g_loss: 0.9563
# Epoch [    1/   50] | d_loss: 0.2529 | g_loss: 0.8038
# Epoch [    1/   50] | d_loss: 0.1609 | g_loss: 0.6967
# Epoch [    1/   50] | d_loss: 0.2336 | g_loss: 0.5521
# Epoch [    1/   50] | d_loss: 0.1430 | g_loss: 0.9485
# Epoch [    1/   50] | d_loss: 0.3359 | g_loss: 0.5409
# Epoch [    1/   50] | d_loss: 0.2292 | g_loss: 0.8249
# Epoch [    1/   50] | d_loss: 0.2139 | g_loss: 0.4950
# Epoch [    1/   50] | d_loss: 0.3084 | g_loss: 0.5863
# Epoch [    1/   50] | d_loss: 0.2546 | g_loss: 0.5783
# Epoch [    2/   50] | d_loss: 0.2576 | g_loss: 0.4694
# Epoch [    2/   50] | d_loss: 0.2929 | g_loss: 0.7095
# Epoch [    2/   50] | d_loss: 0.4714 | g_loss: 0.3809
# Epoch [    2/   50] | d_loss: 0.4223 | g_loss: 0.4583
# Epoch [    2/   50] | d_loss: 0.2937 | g_loss: 0.4570
# Epoch [    2/   50] | d_loss: 0.2843 | g_loss: 0.5269
# Epoch [    2/   50] | d_loss: 0.3449 | g_loss: 1.2403
# Epoch [    2/   50] | d_loss: 0.3868 | g_loss: 0.5196
# Epoch [    2/   50] | d_loss: 0.3977 | g_loss: 0.3918
# Epoch [    2/   50] | d_loss: 0.2995 | g_loss: 0.4931
# Epoch [    2/   50] | d_loss: 0.2879 | g_loss: 0.3860
# Epoch [    2/   50] | d_loss: 0.4011 | g_loss: 0.2787
# Epoch [    2/   50] | d_loss: 0.3870 | g_loss: 0.7243
# Epoch [    2/   50] | d_loss: 0.2853 | g_loss: 1.0365
# Epoch [    2/   50] | d_loss: 0.3610 | g_loss: 0.3555
# Epoch [    3/   50] | d_loss: 0.4638 | g_loss: 0.9750
# Epoch [    3/   50] | d_loss: 0.2947 | g_loss: 0.3214
# Epoch [    3/   50] | d_loss: 0.2317 | g_loss: 0.6095
# Epoch [    3/   50] | d_loss: 0.3994 | g_loss: 0.6448
# Epoch [    3/   50] | d_loss: 0.4216 | g_loss: 0.3409
# Epoch [    3/   50] | d_loss: 0.2748 | g_loss: 0.6598
# Epoch [    3/   50] | d_loss: 0.4132 | g_loss: 0.3171
# Epoch [    3/   50] | d_loss: 0.2961 | g_loss: 0.4452
# Epoch [    3/   50] | d_loss: 0.2082 | g_loss: 0.8709
# Epoch [    3/   50] | d_loss: 0.3168 | g_loss: 0.4906
# Epoch [    3/   50] | d_loss: 0.3746 | g_loss: 0.3912
# Epoch [    3/   50] | d_loss: 0.2483 | g_loss: 0.3763
# Epoch [    3/   50] | d_loss: 0.3336 | g_loss: 0.5248
# Epoch [    3/   50] | d_loss: 0.3488 | g_loss: 0.4373
# Epoch [    3/   50] | d_loss: 0.3981 | g_loss: 0.4709
# Epoch [    4/   50] | d_loss: 0.4606 | g_loss: 0.2938
# Epoch [    4/   50] | d_loss: 0.1647 | g_loss: 0.9314
# Epoch [    4/   50] | d_loss: 0.5144 | g_loss: 0.1567
# Epoch [    4/   50] | d_loss: 0.3264 | g_loss: 0.5003
# Epoch [    4/   50] | d_loss: 0.3185 | g_loss: 0.5544
# Epoch [    4/   50] | d_loss: 0.2863 | g_loss: 0.5836
# Epoch [    4/   50] | d_loss: 0.3454 | g_loss: 0.2757
# Epoch [    4/   50] | d_loss: 0.3521 | g_loss: 0.5601
# Epoch [    4/   50] | d_loss: 0.3830 | g_loss: 0.6641
# Epoch [    4/   50] | d_loss: 0.3071 | g_loss: 0.3829
# Epoch [    4/   50] | d_loss: 0.2571 | g_loss: 0.5716
# Epoch [    4/   50] | d_loss: 0.2874 | g_loss: 0.3878
# Epoch [    4/   50] | d_loss: 0.4531 | g_loss: 0.8147
# Epoch [    4/   50] | d_loss: 0.4010 | g_loss: 0.5462
# Epoch [    4/   50] | d_loss: 0.2666 | g_loss: 0.4260
# Epoch [    5/   50] | d_loss: 0.3021 | g_loss: 0.4320
# Epoch [    5/   50] | d_loss: 0.2951 | g_loss: 0.5896
# Epoch [    5/   50] | d_loss: 0.3791 | g_loss: 0.2947
# Epoch [    5/   50] | d_loss: 0.3587 | g_loss: 0.6166
# Epoch [    5/   50] | d_loss: 0.3528 | g_loss: 0.5527
# Epoch [    5/   50] | d_loss: 0.3715 | g_loss: 0.6084
# Epoch [    5/   50] | d_loss: 0.2484 | g_loss: 0.5380
# Epoch [    5/   50] | d_loss: 0.3010 | g_loss: 0.4188
# Epoch [    5/   50] | d_loss: 0.3167 | g_loss: 0.6163
# Epoch [    5/   50] | d_loss: 0.3523 | g_loss: 0.4359
# Epoch [    5/   50] | d_loss: 0.2722 | g_loss: 0.5757
# Epoch [    5/   50] | d_loss: 0.2957 | g_loss: 0.4383
# Epoch [    5/   50] | d_loss: 0.3600 | g_loss: 0.7491
# Epoch [    5/   50] | d_loss: 0.2604 | g_loss: 0.5242
# Epoch [    5/   50] | d_loss: 0.3171 | g_loss: 0.2804
# Epoch [    6/   50] | d_loss: 0.4089 | g_loss: 0.7987
# Epoch [    6/   50] | d_loss: 0.3365 | g_loss: 0.7080
# Epoch [    6/   50] | d_loss: 0.3063 | g_loss: 0.4189
# Epoch [    6/   50] | d_loss: 0.2400 | g_loss: 0.6311
# Epoch [    6/   50] | d_loss: 0.2923 | g_loss: 0.6081
# Epoch [    6/   50] | d_loss: 0.5583 | g_loss: 0.2358
# Epoch [    6/   50] | d_loss: 0.5621 | g_loss: 0.2000
# Epoch [    6/   50] | d_loss: 0.3623 | g_loss: 0.5701
# Epoch [    6/   50] | d_loss: 0.3294 | g_loss: 0.4871
# Epoch [    6/   50] | d_loss: 0.4052 | g_loss: 0.3472
# Epoch [    6/   50] | d_loss: 0.3642 | g_loss: 0.7357
# Epoch [    6/   50] | d_loss: 0.4008 | g_loss: 0.4981
# Epoch [    6/   50] | d_loss: 0.2671 | g_loss: 0.5514
# Epoch [    6/   50] | d_loss: 0.3720 | g_loss: 0.3640
# Epoch [    6/   50] | d_loss: 0.2632 | g_loss: 0.3825
# Epoch [    7/   50] | d_loss: 0.3515 | g_loss: 0.4615
# Epoch [    7/   50] | d_loss: 0.3019 | g_loss: 0.4912
# Epoch [    7/   50] | d_loss: 0.2245 | g_loss: 0.5084
# Epoch [    7/   50] | d_loss: 0.3027 | g_loss: 0.4469
# Epoch [    7/   50] | d_loss: 0.3367 | g_loss: 0.3721
# Epoch [    7/   50] | d_loss: 0.3427 | g_loss: 0.5855
# Epoch [    7/   50] | d_loss: 0.4433 | g_loss: 0.1764
# Epoch [    7/   50] | d_loss: 0.2929 | g_loss: 0.4180
# Epoch [    7/   50] | d_loss: 0.2080 | g_loss: 0.6204
# Epoch [    7/   50] | d_loss: 0.2203 | g_loss: 0.5421
# Epoch [    7/   50] | d_loss: 0.2901 | g_loss: 0.5293
# Epoch [    7/   50] | d_loss: 0.2513 | g_loss: 0.6244
# Epoch [    7/   50] | d_loss: 0.2807 | g_loss: 0.7334
# Epoch [    7/   50] | d_loss: 0.2648 | g_loss: 0.6809
# Epoch [    7/   50] | d_loss: 0.2431 | g_loss: 0.6362
# Epoch [    8/   50] | d_loss: 0.2762 | g_loss: 0.3623
# Epoch [    8/   50] | d_loss: 0.3004 | g_loss: 0.6167
# Epoch [    8/   50] | d_loss: 0.3228 | g_loss: 0.4637
# Epoch [    8/   50] | d_loss: 0.3235 | g_loss: 0.3551
# Epoch [    8/   50] | d_loss: 0.4219 | g_loss: 0.2029
# Epoch [    8/   50] | d_loss: 0.3091 | g_loss: 0.7794
# Epoch [    8/   50] | d_loss: 0.2770 | g_loss: 0.3311
# Epoch [    8/   50] | d_loss: 0.2525 | g_loss: 0.5553
# Epoch [    8/   50] | d_loss: 0.1819 | g_loss: 0.6374
# Epoch [    8/   50] | d_loss: 0.3387 | g_loss: 0.3172
# Epoch [    8/   50] | d_loss: 0.1968 | g_loss: 0.7743
# Epoch [    8/   50] | d_loss: 0.1728 | g_loss: 0.5104
# Epoch [    8/   50] | d_loss: 0.2474 | g_loss: 0.6789
# Epoch [    8/   50] | d_loss: 0.3668 | g_loss: 0.5357
# Epoch [    8/   50] | d_loss: 0.2575 | g_loss: 0.6401
# Epoch [    9/   50] | d_loss: 0.3243 | g_loss: 0.2924
# Epoch [    9/   50] | d_loss: 0.2031 | g_loss: 0.6901
# Epoch [    9/   50] | d_loss: 0.4699 | g_loss: 0.1337
# Epoch [    9/   50] | d_loss: 0.2876 | g_loss: 0.3399
# Epoch [    9/   50] | d_loss: 0.2985 | g_loss: 0.7775
# Epoch [    9/   50] | d_loss: 0.6106 | g_loss: 0.2758
# Epoch [    9/   50] | d_loss: 0.5114 | g_loss: 0.4794
# Epoch [    9/   50] | d_loss: 0.3343 | g_loss: 0.4813
# Epoch [    9/   50] | d_loss: 0.3397 | g_loss: 0.4376
# Epoch [    9/   50] | d_loss: 0.2486 | g_loss: 0.5366
# Epoch [    9/   50] | d_loss: 0.2720 | g_loss: 0.3629
# Epoch [    9/   50] | d_loss: 0.2210 | g_loss: 0.5759
# Epoch [    9/   50] | d_loss: 0.2225 | g_loss: 0.6178
# Epoch [    9/   50] | d_loss: 0.5298 | g_loss: 0.2847
# Epoch [    9/   50] | d_loss: 0.2503 | g_loss: 0.5089
# Epoch [   10/   50] | d_loss: 0.3073 | g_loss: 0.3928
# Epoch [   10/   50] | d_loss: 0.2403 | g_loss: 0.4811
# Epoch [   10/   50] | d_loss: 0.2533 | g_loss: 0.6566
# Epoch [   10/   50] | d_loss: 0.2773 | g_loss: 0.7970
# Epoch [   10/   50] | d_loss: 0.2195 | g_loss: 0.8275
# Epoch [   10/   50] | d_loss: 0.1224 | g_loss: 0.8767
# Epoch [   10/   50] | d_loss: 0.2346 | g_loss: 0.6956
# Epoch [   10/   50] | d_loss: 0.3273 | g_loss: 0.7178
# Epoch [   10/   50] | d_loss: 0.2695 | g_loss: 0.4968
# Epoch [   10/   50] | d_loss: 0.4019 | g_loss: 0.3628
# Epoch [   10/   50] | d_loss: 0.3212 | g_loss: 0.5391
# Epoch [   10/   50] | d_loss: 0.2982 | g_loss: 0.2932
# Epoch [   10/   50] | d_loss: 0.2368 | g_loss: 0.4541
# Epoch [   10/   50] | d_loss: 0.1934 | g_loss: 0.7932
# Epoch [   10/   50] | d_loss: 0.5871 | g_loss: 0.3929
# Epoch [   11/   50] | d_loss: 0.5163 | g_loss: 0.5853
# Epoch [   11/   50] | d_loss: 0.2277 | g_loss: 0.4798
# Epoch [   11/   50] | d_loss: 0.2483 | g_loss: 0.4460
# Epoch [   11/   50] | d_loss: 0.1668 | g_loss: 1.1314
# Epoch [   11/   50] | d_loss: 0.6920 | g_loss: 0.9873
# Epoch [   11/   50] | d_loss: 0.2762 | g_loss: 0.4771
# Epoch [   11/   50] | d_loss: 0.2264 | g_loss: 0.4680
# Epoch [   11/   50] | d_loss: 0.3655 | g_loss: 0.2991
# Epoch [   11/   50] | d_loss: 1.9859 | g_loss: 1.6502
# Epoch [   11/   50] | d_loss: 0.2333 | g_loss: 0.4183
# Epoch [   11/   50] | d_loss: 0.2214 | g_loss: 0.5676
# Epoch [   11/   50] | d_loss: 0.2774 | g_loss: 0.4656
# Epoch [   11/   50] | d_loss: 0.2299 | g_loss: 0.7725
# Epoch [   11/   50] | d_loss: 0.3504 | g_loss: 0.2993
# Epoch [   11/   50] | d_loss: 0.3217 | g_loss: 0.5671
# Epoch [   12/   50] | d_loss: 0.1919 | g_loss: 0.7612
# Epoch [   12/   50] | d_loss: 0.2466 | g_loss: 0.7097
# Epoch [   12/   50] | d_loss: 0.1757 | g_loss: 0.7608
# Epoch [   12/   50] | d_loss: 0.3234 | g_loss: 0.5638
# Epoch [   12/   50] | d_loss: 0.1742 | g_loss: 0.9154
# Epoch [   12/   50] | d_loss: 0.3163 | g_loss: 0.9144
# Epoch [   12/   50] | d_loss: 0.2705 | g_loss: 0.6287
# Epoch [   12/   50] | d_loss: 0.3518 | g_loss: 0.6956
# Epoch [   12/   50] | d_loss: 0.1882 | g_loss: 0.8011
# Epoch [   12/   50] | d_loss: 0.2082 | g_loss: 0.4314
# Epoch [   12/   50] | d_loss: 0.2966 | g_loss: 0.7031
# Epoch [   12/   50] | d_loss: 0.2770 | g_loss: 0.7161
# Epoch [   12/   50] | d_loss: 0.2600 | g_loss: 0.7431
# Epoch [   12/   50] | d_loss: 0.2356 | g_loss: 0.5300
# Epoch [   12/   50] | d_loss: 0.2784 | g_loss: 0.7297
# Epoch [   13/   50] | d_loss: 0.3071 | g_loss: 0.5355
# Epoch [   13/   50] | d_loss: 0.2736 | g_loss: 0.8698
# Epoch [   13/   50] | d_loss: 0.1674 | g_loss: 0.8067
# Epoch [   13/   50] | d_loss: 0.2103 | g_loss: 0.7791
# Epoch [   13/   50] | d_loss: 0.1786 | g_loss: 0.7662
# Epoch [   13/   50] | d_loss: 0.2442 | g_loss: 0.9066
# Epoch [   13/   50] | d_loss: 0.4165 | g_loss: 0.8609
# Epoch [   13/   50] | d_loss: 0.2154 | g_loss: 0.6722
# Epoch [   13/   50] | d_loss: 0.5440 | g_loss: 1.2627
# Epoch [   13/   50] | d_loss: 0.2802 | g_loss: 0.4478
# Epoch [   13/   50] | d_loss: 0.2693 | g_loss: 0.3890
# Epoch [   13/   50] | d_loss: 0.1910 | g_loss: 0.6505
# Epoch [   13/   50] | d_loss: 0.1846 | g_loss: 0.6688
# Epoch [   13/   50] | d_loss: 0.2078 | g_loss: 0.6855
# Epoch [   13/   50] | d_loss: 0.4370 | g_loss: 1.1135
# Epoch [   14/   50] | d_loss: 0.2513 | g_loss: 0.4426
# Epoch [   14/   50] | d_loss: 0.2432 | g_loss: 0.6443
# Epoch [   14/   50] | d_loss: 0.2080 | g_loss: 0.8520
# Epoch [   14/   50] | d_loss: 0.2226 | g_loss: 0.5870
# Epoch [   14/   50] | d_loss: 0.2469 | g_loss: 0.6234
# Epoch [   14/   50] | d_loss: 0.2398 | g_loss: 0.9189
# Epoch [   14/   50] | d_loss: 0.2527 | g_loss: 0.7781
# Epoch [   14/   50] | d_loss: 0.2394 | g_loss: 0.5319
# Epoch [   14/   50] | d_loss: 0.5889 | g_loss: 1.3337
# Epoch [   14/   50] | d_loss: 0.2277 | g_loss: 0.6955
# Epoch [   14/   50] | d_loss: 0.2038 | g_loss: 0.8172
# Epoch [   14/   50] | d_loss: 0.2027 | g_loss: 0.6208
# Epoch [   14/   50] | d_loss: 0.2134 | g_loss: 0.9070
# Epoch [   14/   50] | d_loss: 0.2892 | g_loss: 1.0041
# Epoch [   14/   50] | d_loss: 0.2024 | g_loss: 0.7067
# Epoch [   15/   50] | d_loss: 0.3199 | g_loss: 0.3577
# Epoch [   15/   50] | d_loss: 0.2457 | g_loss: 0.8604
# Epoch [   15/   50] | d_loss: 0.5872 | g_loss: 0.2563
# Epoch [   15/   50] | d_loss: 0.3509 | g_loss: 0.7099
# Epoch [   15/   50] | d_loss: 0.2639 | g_loss: 0.5638
# Epoch [   15/   50] | d_loss: 0.2276 | g_loss: 0.6287
# Epoch [   15/   50] | d_loss: 0.2759 | g_loss: 0.8844
# Epoch [   15/   50] | d_loss: 0.2266 | g_loss: 0.4809
# Epoch [   15/   50] | d_loss: 0.2745 | g_loss: 0.8325
# Epoch [   15/   50] | d_loss: 0.1838 | g_loss: 0.5306
# Epoch [   15/   50] | d_loss: 0.2009 | g_loss: 0.8146
# Epoch [   15/   50] | d_loss: 0.2627 | g_loss: 0.7350
# Epoch [   15/   50] | d_loss: 0.1674 | g_loss: 0.4729
# Epoch [   15/   50] | d_loss: 0.2065 | g_loss: 0.4920
# Epoch [   15/   50] | d_loss: 0.1713 | g_loss: 0.7459
# Epoch [   16/   50] | d_loss: 0.1584 | g_loss: 0.6101
# Epoch [   16/   50] | d_loss: 0.2408 | g_loss: 0.3589
# Epoch [   16/   50] | d_loss: 0.2330 | g_loss: 0.5505
# Epoch [   16/   50] | d_loss: 0.1801 | g_loss: 0.5112
# Epoch [   16/   50] | d_loss: 1.0225 | g_loss: 1.1016
# Epoch [   16/   50] | d_loss: 0.2515 | g_loss: 0.4893
# Epoch [   16/   50] | d_loss: 0.1942 | g_loss: 0.5357
# Epoch [   16/   50] | d_loss: 0.1818 | g_loss: 0.3722
# Epoch [   16/   50] | d_loss: 0.2253 | g_loss: 0.4188
# Epoch [   16/   50] | d_loss: 0.2354 | g_loss: 0.6899
# Epoch [   16/   50] | d_loss: 0.2287 | g_loss: 1.0637
# Epoch [   16/   50] | d_loss: 0.2307 | g_loss: 0.8685
# Epoch [   16/   50] | d_loss: 0.5928 | g_loss: 0.3271
# Epoch [   16/   50] | d_loss: 0.6015 | g_loss: 0.2845
# Epoch [   16/   50] | d_loss: 0.5539 | g_loss: 0.2618
# Epoch [   17/   50] | d_loss: 0.5735 | g_loss: 0.3151
# Epoch [   17/   50] | d_loss: 0.5555 | g_loss: 0.2687
# Epoch [   17/   50] | d_loss: 0.6106 | g_loss: 0.2865
# Epoch [   17/   50] | d_loss: 0.5195 | g_loss: 0.2625
# Epoch [   17/   50] | d_loss: 0.5627 | g_loss: 0.2387
# Epoch [   17/   50] | d_loss: 0.5384 | g_loss: 0.2787
# Epoch [   17/   50] | d_loss: 0.5122 | g_loss: 0.2636
# Epoch [   17/   50] | d_loss: 0.5225 | g_loss: 0.2548
# Epoch [   17/   50] | d_loss: 0.5882 | g_loss: 0.2292
# Epoch [   17/   50] | d_loss: 0.5238 | g_loss: 0.2630
# Epoch [   17/   50] | d_loss: 0.5116 | g_loss: 0.2720
# Epoch [   17/   50] | d_loss: 0.4853 | g_loss: 0.2760
# Epoch [   17/   50] | d_loss: 0.4947 | g_loss: 0.2656
# Epoch [   17/   50] | d_loss: 0.5090 | g_loss: 0.2599
# Epoch [   17/   50] | d_loss: 0.5046 | g_loss: 0.2945
# Epoch [   18/   50] | d_loss: 0.5525 | g_loss: 0.2761
# Epoch [   18/   50] | d_loss: 0.5090 | g_loss: 0.2990
# Epoch [   18/   50] | d_loss: 0.5347 | g_loss: 0.2734
# Epoch [   18/   50] | d_loss: 0.5012 | g_loss: 0.2646
# Epoch [   18/   50] | d_loss: 0.5335 | g_loss: 0.2575
# Epoch [   18/   50] | d_loss: 0.5212 | g_loss: 0.2687
# Epoch [   18/   50] | d_loss: 0.5099 | g_loss: 0.2536
# Epoch [   18/   50] | d_loss: 0.5016 | g_loss: 0.2615
# Epoch [   18/   50] | d_loss: 0.5120 | g_loss: 0.2418
# Epoch [   18/   50] | d_loss: 0.4887 | g_loss: 0.2709
# Epoch [   18/   50] | d_loss: 0.5535 | g_loss: 0.2461
# Epoch [   18/   50] | d_loss: 0.5040 | g_loss: 0.3074
# Epoch [   18/   50] | d_loss: 0.5184 | g_loss: 0.3240
# Epoch [   18/   50] | d_loss: 0.5244 | g_loss: 0.2823
# Epoch [   18/   50] | d_loss: 0.4870 | g_loss: 0.3234
# Epoch [   19/   50] | d_loss: 0.4712 | g_loss: 0.2988
# Epoch [   19/   50] | d_loss: 0.5092 | g_loss: 0.2620
# Epoch [   19/   50] | d_loss: 0.5434 | g_loss: 0.2587
# Epoch [   19/   50] | d_loss: 0.4815 | g_loss: 0.2548
# Epoch [   19/   50] | d_loss: 0.5036 | g_loss: 0.2757
# Epoch [   19/   50] | d_loss: 0.5100 | g_loss: 0.2862
# Epoch [   19/   50] | d_loss: 0.5037 | g_loss: 0.2662
# Epoch [   19/   50] | d_loss: 0.5180 | g_loss: 0.2695
# Epoch [   19/   50] | d_loss: 0.5040 | g_loss: 0.2809
# Epoch [   19/   50] | d_loss: 0.4941 | g_loss: 0.2660
# Epoch [   19/   50] | d_loss: 0.5075 | g_loss: 0.2712
# Epoch [   19/   50] | d_loss: 0.5366 | g_loss: 0.2970
# Epoch [   19/   50] | d_loss: 0.5285 | g_loss: 0.2660
# Epoch [   19/   50] | d_loss: 0.5271 | g_loss: 0.2662
# Epoch [   19/   50] | d_loss: 0.5151 | g_loss: 0.2895
# Epoch [   20/   50] | d_loss: 0.5138 | g_loss: 0.2597
# Epoch [   20/   50] | d_loss: 0.5551 | g_loss: 0.2369
# Epoch [   20/   50] | d_loss: 0.5051 | g_loss: 0.2700
# Epoch [   20/   50] | d_loss: 0.5642 | g_loss: 0.3194
# Epoch [   20/   50] | d_loss: 0.5584 | g_loss: 0.2818
# Epoch [   20/   50] | d_loss: 0.5603 | g_loss: 0.2704
# Epoch [   20/   50] | d_loss: 0.5043 | g_loss: 0.3012
# Epoch [   20/   50] | d_loss: 0.4929 | g_loss: 0.2884
# Epoch [   20/   50] | d_loss: 0.5417 | g_loss: 0.2469
# Epoch [   20/   50] | d_loss: 0.5103 | g_loss: 0.2864
# Epoch [   20/   50] | d_loss: 0.5412 | g_loss: 0.2406
# Epoch [   20/   50] | d_loss: 0.5678 | g_loss: 0.2445
# Epoch [   20/   50] | d_loss: 0.5451 | g_loss: 0.2748
# Epoch [   20/   50] | d_loss: 0.5760 | g_loss: 0.2206
# Epoch [   20/   50] | d_loss: 0.5147 | g_loss: 0.3005
# Epoch [   21/   50] | d_loss: 0.5166 | g_loss: 0.2673
# Epoch [   21/   50] | d_loss: 0.5142 | g_loss: 0.2970
# Epoch [   21/   50] | d_loss: 0.4925 | g_loss: 0.2911
# Epoch [   21/   50] | d_loss: 0.5008 | g_loss: 0.3105
# Epoch [   21/   50] | d_loss: 0.5062 | g_loss: 0.2821
# Epoch [   21/   50] | d_loss: 0.5293 | g_loss: 0.3166
# Epoch [   21/   50] | d_loss: 0.5071 | g_loss: 0.2986
# Epoch [   21/   50] | d_loss: 0.4692 | g_loss: 0.2754
# Epoch [   21/   50] | d_loss: 0.4544 | g_loss: 0.2965
# Epoch [   21/   50] | d_loss: 0.5213 | g_loss: 0.3058
# Epoch [   21/   50] | d_loss: 0.5062 | g_loss: 0.2576
# Epoch [   21/   50] | d_loss: 0.4851 | g_loss: 0.2784
# Epoch [   21/   50] | d_loss: 0.5271 | g_loss: 0.2880
# Epoch [   21/   50] | d_loss: 0.5009 | g_loss: 0.2931
# Epoch [   21/   50] | d_loss: 0.5170 | g_loss: 0.2858
# Epoch [   22/   50] | d_loss: 0.4807 | g_loss: 0.3176
# Epoch [   22/   50] | d_loss: 0.4582 | g_loss: 0.2498
# Epoch [   22/   50] | d_loss: 0.5743 | g_loss: 0.2406
# Epoch [   22/   50] | d_loss: 0.5371 | g_loss: 0.2548
# Epoch [   22/   50] | d_loss: 0.5277 | g_loss: 0.2605
# Epoch [   22/   50] | d_loss: 0.4879 | g_loss: 0.2712
# Epoch [   22/   50] | d_loss: 0.4867 | g_loss: 0.3416
# Epoch [   22/   50] | d_loss: 0.4819 | g_loss: 0.2694
# Epoch [   22/   50] | d_loss: 0.5119 | g_loss: 0.2393
# Epoch [   22/   50] | d_loss: 0.4582 | g_loss: 0.2526
# Epoch [   22/   50] | d_loss: 0.5038 | g_loss: 0.3383
# Epoch [   22/   50] | d_loss: 0.4939 | g_loss: 0.2747
# Epoch [   22/   50] | d_loss: 0.4848 | g_loss: 0.2794
# Epoch [   22/   50] | d_loss: 0.5506 | g_loss: 0.2258
# Epoch [   22/   50] | d_loss: 0.4953 | g_loss: 0.3121
# Epoch [   23/   50] | d_loss: 0.5631 | g_loss: 0.2668
# Epoch [   23/   50] | d_loss: 0.4867 | g_loss: 0.3738
# Epoch [   23/   50] | d_loss: 0.5069 | g_loss: 0.3143
# Epoch [   23/   50] | d_loss: 0.4996 | g_loss: 0.4665
# Epoch [   23/   50] | d_loss: 0.5337 | g_loss: 0.4155
# Epoch [   23/   50] | d_loss: 0.5023 | g_loss: 0.3450
# Epoch [   23/   50] | d_loss: 0.6660 | g_loss: 0.0744
# Epoch [   23/   50] | d_loss: 0.5211 | g_loss: 0.2414
# Epoch [   23/   50] | d_loss: 0.4860 | g_loss: 0.3558
# Epoch [   23/   50] | d_loss: 0.4799 | g_loss: 0.3251
# Epoch [   23/   50] | d_loss: 0.5080 | g_loss: 0.3237
# Epoch [   23/   50] | d_loss: 0.5207 | g_loss: 0.2193
# Epoch [   23/   50] | d_loss: 0.4681 | g_loss: 0.2715
# Epoch [   23/   50] | d_loss: 0.5149 | g_loss: 0.3311
# Epoch [   23/   50] | d_loss: 0.4856 | g_loss: 0.2688
# Epoch [   24/   50] | d_loss: 0.4716 | g_loss: 0.3383
# Epoch [   24/   50] | d_loss: 0.5080 | g_loss: 0.4552
# Epoch [   24/   50] | d_loss: 0.5153 | g_loss: 0.2562
# Epoch [   24/   50] | d_loss: 0.5186 | g_loss: 0.3417
# Epoch [   24/   50] | d_loss: 0.5289 | g_loss: 0.1607
# Epoch [   24/   50] | d_loss: 0.5129 | g_loss: 0.2375
# Epoch [   24/   50] | d_loss: 0.5224 | g_loss: 0.2711
# Epoch [   24/   50] | d_loss: 0.4993 | g_loss: 0.3314
# Epoch [   24/   50] | d_loss: 0.5430 | g_loss: 0.2891
# Epoch [   24/   50] | d_loss: 0.5387 | g_loss: 0.3234
# Epoch [   24/   50] | d_loss: 0.5183 | g_loss: 0.3332
# Epoch [   24/   50] | d_loss: 0.5182 | g_loss: 0.3044
# Epoch [   24/   50] | d_loss: 0.5194 | g_loss: 0.3018
# Epoch [   24/   50] | d_loss: 0.4848 | g_loss: 0.2378
# Epoch [   24/   50] | d_loss: 0.5005 | g_loss: 0.3870
# Epoch [   25/   50] | d_loss: 0.5019 | g_loss: 0.2560
# Epoch [   25/   50] | d_loss: 0.5463 | g_loss: 0.3123
# Epoch [   25/   50] | d_loss: 0.4719 | g_loss: 0.3166
# Epoch [   25/   50] | d_loss: 0.4695 | g_loss: 0.2856
# Epoch [   25/   50] | d_loss: 0.5197 | g_loss: 0.3167
# Epoch [   25/   50] | d_loss: 0.5033 | g_loss: 0.2865
# Epoch [   25/   50] | d_loss: 0.4928 | g_loss: 0.2239
# Epoch [   25/   50] | d_loss: 0.4949 | g_loss: 0.2828
# Epoch [   25/   50] | d_loss: 0.5111 | g_loss: 0.2684
# Epoch [   25/   50] | d_loss: 0.5031 | g_loss: 0.2298
# Epoch [   25/   50] | d_loss: 0.4982 | g_loss: 0.2369
# Epoch [   25/   50] | d_loss: 0.5075 | g_loss: 0.2722
# Epoch [   25/   50] | d_loss: 0.4895 | g_loss: 0.2384
# Epoch [   25/   50] | d_loss: 0.5043 | g_loss: 0.2633
# Epoch [   25/   50] | d_loss: 0.5023 | g_loss: 0.2653
# Epoch [   26/   50] | d_loss: 0.5010 | g_loss: 0.2925
# Epoch [   26/   50] | d_loss: 0.5058 | g_loss: 0.2501
# Epoch [   26/   50] | d_loss: 0.5203 | g_loss: 0.2391
# Epoch [   26/   50] | d_loss: 0.5052 | g_loss: 0.2644
# Epoch [   26/   50] | d_loss: 0.4942 | g_loss: 0.2564
# Epoch [   26/   50] | d_loss: 0.4914 | g_loss: 0.2598
# Epoch [   26/   50] | d_loss: 0.5187 | g_loss: 0.2760
# Epoch [   26/   50] | d_loss: 0.4987 | g_loss: 0.2953
# Epoch [   26/   50] | d_loss: 0.5137 | g_loss: 0.2678
# Epoch [   26/   50] | d_loss: 0.4908 | g_loss: 0.2427
# Epoch [   26/   50] | d_loss: 0.5030 | g_loss: 0.2396
# Epoch [   26/   50] | d_loss: 0.5035 | g_loss: 0.2813
# Epoch [   26/   50] | d_loss: 0.5304 | g_loss: 0.2666
# Epoch [   26/   50] | d_loss: 0.5549 | g_loss: 0.2495
# Epoch [   26/   50] | d_loss: 0.5033 | g_loss: 0.2766
# Epoch [   27/   50] | d_loss: 0.4892 | g_loss: 0.3074
# Epoch [   27/   50] | d_loss: 0.4978 | g_loss: 0.2608
# Epoch [   27/   50] | d_loss: 0.4951 | g_loss: 0.2944
# Epoch [   27/   50] | d_loss: 0.5143 | g_loss: 0.2856
# Epoch [   27/   50] | d_loss: 0.5155 | g_loss: 0.2581
# Epoch [   27/   50] | d_loss: 0.5133 | g_loss: 0.2980
# Epoch [   27/   50] | d_loss: 0.5089 | g_loss: 0.2478
# Epoch [   27/   50] | d_loss: 0.4785 | g_loss: 0.2660
# Epoch [   27/   50] | d_loss: 0.4995 | g_loss: 0.2503
# Epoch [   27/   50] | d_loss: 0.5229 | g_loss: 0.2810
# Epoch [   27/   50] | d_loss: 0.4885 | g_loss: 0.2631
# Epoch [   27/   50] | d_loss: 0.5133 | g_loss: 0.3072
# Epoch [   27/   50] | d_loss: 0.4851 | g_loss: 0.2621
# Epoch [   27/   50] | d_loss: 0.5137 | g_loss: 0.2811
# Epoch [   27/   50] | d_loss: 0.5246 | g_loss: 0.2626
# Epoch [   28/   50] | d_loss: 0.5098 | g_loss: 0.2710
# Epoch [   28/   50] | d_loss: 0.5119 | g_loss: 0.2778
# Epoch [   28/   50] | d_loss: 0.5192 | g_loss: 0.2685
# Epoch [   28/   50] | d_loss: 0.4969 | g_loss: 0.2444
# Epoch [   28/   50] | d_loss: 0.4922 | g_loss: 0.2898
# Epoch [   28/   50] | d_loss: 0.4932 | g_loss: 0.2800
# Epoch [   28/   50] | d_loss: 0.5026 | g_loss: 0.2529
# Epoch [   28/   50] | d_loss: 0.5204 | g_loss: 0.2700
# Epoch [   28/   50] | d_loss: 0.4903 | g_loss: 0.3109
# Epoch [   28/   50] | d_loss: 0.5141 | g_loss: 0.2781
# Epoch [   28/   50] | d_loss: 0.4585 | g_loss: 0.3004
# Epoch [   28/   50] | d_loss: 0.5104 | g_loss: 0.2668
# Epoch [   28/   50] | d_loss: 0.4970 | g_loss: 0.2716
# Epoch [   28/   50] | d_loss: 0.5279 | g_loss: 0.3211
# Epoch [   28/   50] | d_loss: 0.4809 | g_loss: 0.2410
# Epoch [   29/   50] | d_loss: 0.4914 | g_loss: 0.2655
# Epoch [   29/   50] | d_loss: 0.5044 | g_loss: 0.3055
# Epoch [   29/   50] | d_loss: 0.4956 | g_loss: 0.3378
# Epoch [   29/   50] | d_loss: 0.4788 | g_loss: 0.2553
# Epoch [   29/   50] | d_loss: 0.5237 | g_loss: 0.2227
# Epoch [   29/   50] | d_loss: 0.5088 | g_loss: 0.2922
# Epoch [   29/   50] | d_loss: 0.5223 | g_loss: 0.2877
# Epoch [   29/   50] | d_loss: 0.5090 | g_loss: 0.2655
# Epoch [   29/   50] | d_loss: 0.5250 | g_loss: 0.2791
# Epoch [   29/   50] | d_loss: 0.5083 | g_loss: 0.2941
# Epoch [   29/   50] | d_loss: 0.4991 | g_loss: 0.2926
# Epoch [   29/   50] | d_loss: 0.4962 | g_loss: 0.2672
# Epoch [   29/   50] | d_loss: 0.4958 | g_loss: 0.3029
# Epoch [   29/   50] | d_loss: 0.4971 | g_loss: 0.2962
# Epoch [   29/   50] | d_loss: 0.5169 | g_loss: 0.3023
# Epoch [   30/   50] | d_loss: 0.5109 | g_loss: 0.2844
# Epoch [   30/   50] | d_loss: 0.4619 | g_loss: 0.3470
# Epoch [   30/   50] | d_loss: 0.5079 | g_loss: 0.2424
# Epoch [   30/   50] | d_loss: 0.4815 | g_loss: 0.2771
# Epoch [   30/   50] | d_loss: 0.5187 | g_loss: 0.2541
# Epoch [   30/   50] | d_loss: 0.4812 | g_loss: 0.2851
# Epoch [   30/   50] | d_loss: 0.5201 | g_loss: 0.2359
# Epoch [   30/   50] | d_loss: 0.5046 | g_loss: 0.2642
# Epoch [   30/   50] | d_loss: 0.5225 | g_loss: 0.2763
# Epoch [   30/   50] | d_loss: 0.5194 | g_loss: 0.2249
# Epoch [   30/   50] | d_loss: 0.5349 | g_loss: 0.2707
# Epoch [   30/   50] | d_loss: 0.4929 | g_loss: 0.3029
# Epoch [   30/   50] | d_loss: 0.5057 | g_loss: 0.2671
# Epoch [   30/   50] | d_loss: 0.4923 | g_loss: 0.3186
# Epoch [   30/   50] | d_loss: 0.5013 | g_loss: 0.3173
# Epoch [   31/   50] | d_loss: 0.5175 | g_loss: 0.2941
# Epoch [   31/   50] | d_loss: 0.4984 | g_loss: 0.2538
# Epoch [   31/   50] | d_loss: 0.5132 | g_loss: 0.2753
# Epoch [   31/   50] | d_loss: 0.4876 | g_loss: 0.2809
# Epoch [   31/   50] | d_loss: 0.4961 | g_loss: 0.2702
# Epoch [   31/   50] | d_loss: 0.5191 | g_loss: 0.2648
# Epoch [   31/   50] | d_loss: 0.5093 | g_loss: 0.3184
# Epoch [   31/   50] | d_loss: 0.5021 | g_loss: 0.2773
# Epoch [   31/   50] | d_loss: 0.5061 | g_loss: 0.2704
# Epoch [   31/   50] | d_loss: 0.4985 | g_loss: 0.2679
# Epoch [   31/   50] | d_loss: 0.4886 | g_loss: 0.3230
# Epoch [   31/   50] | d_loss: 0.5169 | g_loss: 0.2730
# Epoch [   31/   50] | d_loss: 0.4952 | g_loss: 0.2841
# Epoch [   31/   50] | d_loss: 0.5266 | g_loss: 0.2704
# Epoch [   31/   50] | d_loss: 0.5179 | g_loss: 0.2596
# Epoch [   32/   50] | d_loss: 0.5032 | g_loss: 0.2796
# Epoch [   32/   50] | d_loss: 0.4852 | g_loss: 0.2673
# Epoch [   32/   50] | d_loss: 0.4988 | g_loss: 0.2800
# Epoch [   32/   50] | d_loss: 0.5046 | g_loss: 0.2990
# Epoch [   32/   50] | d_loss: 0.5026 | g_loss: 0.2378
# Epoch [   32/   50] | d_loss: 0.5375 | g_loss: 0.2261
# Epoch [   32/   50] | d_loss: 0.4928 | g_loss: 0.2613
# Epoch [   32/   50] | d_loss: 0.5050 | g_loss: 0.2569
# Epoch [   32/   50] | d_loss: 0.5172 | g_loss: 0.2935
# Epoch [   32/   50] | d_loss: 0.5025 | g_loss: 0.3185
# Epoch [   32/   50] | d_loss: 0.4710 | g_loss: 0.2680
# Epoch [   32/   50] | d_loss: 0.4840 | g_loss: 0.2756
# Epoch [   32/   50] | d_loss: 0.4753 | g_loss: 0.2997
# Epoch [   32/   50] | d_loss: 0.4883 | g_loss: 0.1878
# Epoch [   32/   50] | d_loss: 0.4872 | g_loss: 0.2475
# Epoch [   33/   50] | d_loss: 0.4923 | g_loss: 0.2736
# Epoch [   33/   50] | d_loss: 0.5105 | g_loss: 0.2566
# Epoch [   33/   50] | d_loss: 0.4937 | g_loss: 0.2432
# Epoch [   33/   50] | d_loss: 0.5297 | g_loss: 0.2975
# Epoch [   33/   50] | d_loss: 0.5028 | g_loss: 0.3203
# Epoch [   33/   50] | d_loss: 0.5003 | g_loss: 0.2903
# Epoch [   33/   50] | d_loss: 0.4958 | g_loss: 0.2530
# Epoch [   33/   50] | d_loss: 0.4964 | g_loss: 0.2755
# Epoch [   33/   50] | d_loss: 0.5157 | g_loss: 0.2703
# Epoch [   33/   50] | d_loss: 0.5058 | g_loss: 0.2038
# Epoch [   33/   50] | d_loss: 0.5141 | g_loss: 0.2650
# Epoch [   33/   50] | d_loss: 0.4994 | g_loss: 0.2675
# Epoch [   33/   50] | d_loss: 0.5066 | g_loss: 0.2819
# Epoch [   33/   50] | d_loss: 0.5171 | g_loss: 0.2286
# Epoch [   33/   50] | d_loss: 0.5221 | g_loss: 0.3505
# Epoch [   34/   50] | d_loss: 0.4982 | g_loss: 0.2847
# Epoch [   34/   50] | d_loss: 0.5111 | g_loss: 0.2661
# Epoch [   34/   50] | d_loss: 0.4710 | g_loss: 0.2759
# Epoch [   34/   50] | d_loss: 0.4553 | g_loss: 0.2509
# Epoch [   34/   50] | d_loss: 0.5009 | g_loss: 0.2582
# Epoch [   34/   50] | d_loss: 0.5343 | g_loss: 0.2693
# Epoch [   34/   50] | d_loss: 0.4995 | g_loss: 0.3158
# Epoch [   34/   50] | d_loss: 0.5106 | g_loss: 0.2959
# Epoch [   34/   50] | d_loss: 0.5026 | g_loss: 0.3145
# Epoch [   34/   50] | d_loss: 0.4865 | g_loss: 0.2500
# Epoch [   34/   50] | d_loss: 0.5019 | g_loss: 0.3581
# Epoch [   34/   50] | d_loss: 0.4679 | g_loss: 0.2872
# Epoch [   34/   50] | d_loss: 0.5242 | g_loss: 0.2864
# Epoch [   34/   50] | d_loss: 0.5092 | g_loss: 0.2560
# Epoch [   34/   50] | d_loss: 0.5066 | g_loss: 0.2751
# Epoch [   35/   50] | d_loss: 0.5190 | g_loss: 0.2971
# Epoch [   35/   50] | d_loss: 0.4866 | g_loss: 0.3368
# Epoch [   35/   50] | d_loss: 0.4716 | g_loss: 0.2685
# Epoch [   35/   50] | d_loss: 0.5169 | g_loss: 0.2747
# Epoch [   35/   50] | d_loss: 0.4780 | g_loss: 0.3127
# Epoch [   35/   50] | d_loss: 0.4861 | g_loss: 0.2717
# Epoch [   35/   50] | d_loss: 0.4920 | g_loss: 0.2911
# Epoch [   35/   50] | d_loss: 0.4746 | g_loss: 0.3031
# Epoch [   35/   50] | d_loss: 0.4733 | g_loss: 0.3112
# Epoch [   35/   50] | d_loss: 0.4925 | g_loss: 0.2982
# Epoch [   35/   50] | d_loss: 0.4615 | g_loss: 0.3587
# Epoch [   35/   50] | d_loss: 0.4854 | g_loss: 0.3278
# Epoch [   35/   50] | d_loss: 0.5136 | g_loss: 0.2493
# Epoch [   35/   50] | d_loss: 0.4904 | g_loss: 0.3365
# Epoch [   35/   50] | d_loss: 0.4869 | g_loss: 0.3162
# Epoch [   36/   50] | d_loss: 0.5051 | g_loss: 0.3102
# Epoch [   36/   50] | d_loss: 0.5497 | g_loss: 0.2763
# Epoch [   36/   50] | d_loss: 0.4560 | g_loss: 0.2829
# Epoch [   36/   50] | d_loss: 0.5485 | g_loss: 0.5056
# Epoch [   36/   50] | d_loss: 0.4301 | g_loss: 0.3481
# Epoch [   36/   50] | d_loss: 0.4884 | g_loss: 0.3933
# Epoch [   36/   50] | d_loss: 0.4648 | g_loss: 0.2668
# Epoch [   36/   50] | d_loss: 0.4850 | g_loss: 0.3248
# Epoch [   36/   50] | d_loss: 0.4782 | g_loss: 0.3300
# Epoch [   36/   50] | d_loss: 0.4812 | g_loss: 0.3108
# Epoch [   36/   50] | d_loss: 0.5027 | g_loss: 0.2750
# Epoch [   36/   50] | d_loss: 0.4885 | g_loss: 0.4139
# Epoch [   36/   50] | d_loss: 0.4318 | g_loss: 0.3592
# Epoch [   36/   50] | d_loss: 0.4031 | g_loss: 0.3394
# Epoch [   36/   50] | d_loss: 0.4489 | g_loss: 0.5270
# Epoch [   37/   50] | d_loss: 0.4548 | g_loss: 0.4275
# Epoch [   37/   50] | d_loss: 0.4296 | g_loss: 0.3552
# Epoch [   37/   50] | d_loss: 0.5376 | g_loss: 0.6912
# Epoch [   37/   50] | d_loss: 0.4303 | g_loss: 0.5532
# Epoch [   37/   50] | d_loss: 0.3973 | g_loss: 0.5071
# Epoch [   37/   50] | d_loss: 0.4544 | g_loss: 0.5805
# Epoch [   37/   50] | d_loss: 0.4403 | g_loss: 0.4095
# Epoch [   37/   50] | d_loss: 0.4811 | g_loss: 0.3535
# Epoch [   37/   50] | d_loss: 0.4005 | g_loss: 0.2851
# Epoch [   37/   50] | d_loss: 0.4431 | g_loss: 0.3386
# Epoch [   37/   50] | d_loss: 0.4701 | g_loss: 0.5692
# Epoch [   37/   50] | d_loss: 0.4378 | g_loss: 0.4090
# Epoch [   37/   50] | d_loss: 0.4025 | g_loss: 0.4681
# Epoch [   37/   50] | d_loss: 0.4320 | g_loss: 0.5426
# Epoch [   37/   50] | d_loss: 0.4048 | g_loss: 0.4208
# Epoch [   38/   50] | d_loss: 0.4335 | g_loss: 0.3694
# Epoch [   38/   50] | d_loss: 0.4318 | g_loss: 0.5097
# Epoch [   38/   50] | d_loss: 0.4093 | g_loss: 0.2635
# Epoch [   38/   50] | d_loss: 0.4044 | g_loss: 0.3644
# Epoch [   38/   50] | d_loss: 0.4293 | g_loss: 0.4480
# Epoch [   38/   50] | d_loss: 0.3783 | g_loss: 0.3736
# Epoch [   38/   50] | d_loss: 0.4231 | g_loss: 0.4262
# Epoch [   38/   50] | d_loss: 0.4605 | g_loss: 0.2687
# Epoch [   38/   50] | d_loss: 0.3604 | g_loss: 0.3797
# Epoch [   38/   50] | d_loss: 0.4098 | g_loss: 0.2148
# Epoch [   38/   50] | d_loss: 0.3961 | g_loss: 0.4793
# Epoch [   38/   50] | d_loss: 0.4091 | g_loss: 0.3528
# Epoch [   38/   50] | d_loss: 0.4029 | g_loss: 0.4689
# Epoch [   38/   50] | d_loss: 0.3952 | g_loss: 0.3070
# Epoch [   38/   50] | d_loss: 0.4182 | g_loss: 0.2998
# Epoch [   39/   50] | d_loss: 0.4156 | g_loss: 0.2945
# Epoch [   39/   50] | d_loss: 0.3337 | g_loss: 0.3739
# Epoch [   39/   50] | d_loss: 0.3757 | g_loss: 0.4026
# Epoch [   39/   50] | d_loss: 0.4713 | g_loss: 0.3499
# Epoch [   39/   50] | d_loss: 0.3974 | g_loss: 0.5050
# Epoch [   39/   50] | d_loss: 0.3361 | g_loss: 0.5256
# Epoch [   39/   50] | d_loss: 0.3357 | g_loss: 0.4868
# Epoch [   39/   50] | d_loss: 0.4077 | g_loss: 0.3776
# Epoch [   39/   50] | d_loss: 0.3597 | g_loss: 0.4874
# Epoch [   39/   50] | d_loss: 0.3618 | g_loss: 0.4037
# Epoch [   39/   50] | d_loss: 0.3757 | g_loss: 0.4482
# Epoch [   39/   50] | d_loss: 0.5263 | g_loss: 0.5668
# Epoch [   39/   50] | d_loss: 0.3953 | g_loss: 0.3963
# Epoch [   39/   50] | d_loss: 0.3380 | g_loss: 0.3799
# Epoch [   39/   50] | d_loss: 0.3513 | g_loss: 0.6007
# Epoch [   40/   50] | d_loss: 0.3864 | g_loss: 0.3560
# Epoch [   40/   50] | d_loss: 0.3845 | g_loss: 0.3890
# Epoch [   40/   50] | d_loss: 0.4865 | g_loss: 0.8265
# Epoch [   40/   50] | d_loss: 0.3772 | g_loss: 0.3453
# Epoch [   40/   50] | d_loss: 0.3951 | g_loss: 0.5288
# Epoch [   40/   50] | d_loss: 0.3483 | g_loss: 0.4087
# Epoch [   40/   50] | d_loss: 0.3472 | g_loss: 0.4533
# Epoch [   40/   50] | d_loss: 0.3898 | g_loss: 0.4596
# Epoch [   40/   50] | d_loss: 0.3170 | g_loss: 0.3825
# Epoch [   40/   50] | d_loss: 0.4148 | g_loss: 0.4679
# Epoch [   40/   50] | d_loss: 0.3925 | g_loss: 0.4744
# Epoch [   40/   50] | d_loss: 0.3787 | g_loss: 0.3315
# Epoch [   40/   50] | d_loss: 0.3608 | g_loss: 0.6026
# Epoch [   40/   50] | d_loss: 0.3423 | g_loss: 0.5644
# Epoch [   40/   50] | d_loss: 0.3171 | g_loss: 0.5204
# Epoch [   41/   50] | d_loss: 0.3213 | g_loss: 0.3358
# Epoch [   41/   50] | d_loss: 0.2768 | g_loss: 0.4351
# Epoch [   41/   50] | d_loss: 0.3583 | g_loss: 0.6823
# Epoch [   41/   50] | d_loss: 0.2804 | g_loss: 0.5203
# Epoch [   41/   50] | d_loss: 0.4419 | g_loss: 0.6223
# Epoch [   41/   50] | d_loss: 0.2862 | g_loss: 0.4271
# Epoch [   41/   50] | d_loss: 0.2947 | g_loss: 0.5005
# Epoch [   41/   50] | d_loss: 0.3841 | g_loss: 0.3045
# Epoch [   41/   50] | d_loss: 0.3032 | g_loss: 0.6536
# Epoch [   41/   50] | d_loss: 0.3277 | g_loss: 0.4633
# Epoch [   41/   50] | d_loss: 0.3958 | g_loss: 0.5248
# Epoch [   41/   50] | d_loss: 0.2992 | g_loss: 0.3691
# Epoch [   41/   50] | d_loss: 0.3548 | g_loss: 0.7123
# Epoch [   41/   50] | d_loss: 0.3866 | g_loss: 0.3638
# Epoch [   41/   50] | d_loss: 0.3117 | g_loss: 0.4483
# Epoch [   42/   50] | d_loss: 0.4040 | g_loss: 0.7420
# Epoch [   42/   50] | d_loss: 0.2842 | g_loss: 0.5069
# Epoch [   42/   50] | d_loss: 0.3326 | g_loss: 0.3282
# Epoch [   42/   50] | d_loss: 0.3260 | g_loss: 0.6234
# Epoch [   42/   50] | d_loss: 0.3985 | g_loss: 0.7180
# Epoch [   42/   50] | d_loss: 0.3300 | g_loss: 0.5269
# Epoch [   42/   50] | d_loss: 0.3467 | g_loss: 0.2601
# Epoch [   42/   50] | d_loss: 0.4536 | g_loss: 0.2018
# Epoch [   42/   50] | d_loss: 0.4026 | g_loss: 0.4912
# Epoch [   42/   50] | d_loss: 0.3724 | g_loss: 0.3733
# Epoch [   42/   50] | d_loss: 0.3449 | g_loss: 0.3530
# Epoch [   42/   50] | d_loss: 0.3063 | g_loss: 0.3701
# Epoch [   42/   50] | d_loss: 0.2510 | g_loss: 0.5930
# Epoch [   42/   50] | d_loss: 0.2960 | g_loss: 0.4884
# Epoch [   42/   50] | d_loss: 0.2395 | g_loss: 0.6729
# Epoch [   43/   50] | d_loss: 0.2639 | g_loss: 0.6674
# Epoch [   43/   50] | d_loss: 0.3237 | g_loss: 0.3651
# Epoch [   43/   50] | d_loss: 0.4262 | g_loss: 0.6489
# Epoch [   43/   50] | d_loss: 0.2921 | g_loss: 0.6549
# Epoch [   43/   50] | d_loss: 0.2881 | g_loss: 0.3841
# Epoch [   43/   50] | d_loss: 0.2282 | g_loss: 0.5247
# Epoch [   43/   50] | d_loss: 0.2946 | g_loss: 0.4133
# Epoch [   43/   50] | d_loss: 0.2975 | g_loss: 0.3202
# Epoch [   43/   50] | d_loss: 0.2997 | g_loss: 0.5539
# Epoch [   43/   50] | d_loss: 0.2801 | g_loss: 0.2867
# Epoch [   43/   50] | d_loss: 0.2637 | g_loss: 0.5488
# Epoch [   43/   50] | d_loss: 0.3884 | g_loss: 0.1983
# Epoch [   43/   50] | d_loss: 0.3202 | g_loss: 0.3718
# Epoch [   43/   50] | d_loss: 0.3817 | g_loss: 0.4420
# Epoch [   43/   50] | d_loss: 0.2758 | g_loss: 0.4819
# Epoch [   44/   50] | d_loss: 0.2907 | g_loss: 0.5060
# Epoch [   44/   50] | d_loss: 0.4228 | g_loss: 0.2846
# Epoch [   44/   50] | d_loss: 0.3018 | g_loss: 0.4777
# Epoch [   44/   50] | d_loss: 0.2946 | g_loss: 0.6802
# Epoch [   44/   50] | d_loss: 0.2837 | g_loss: 0.4591
# Epoch [   44/   50] | d_loss: 0.2783 | g_loss: 0.4381
# Epoch [   44/   50] | d_loss: 0.2529 | g_loss: 0.3486
# Epoch [   44/   50] | d_loss: 0.2730 | g_loss: 0.3934
# Epoch [   44/   50] | d_loss: 0.3113 | g_loss: 0.8414
# Epoch [   44/   50] | d_loss: 0.5819 | g_loss: 1.2857
# Epoch [   44/   50] | d_loss: 0.3774 | g_loss: 0.6756
# Epoch [   44/   50] | d_loss: 0.2996 | g_loss: 0.5465
# Epoch [   44/   50] | d_loss: 0.2988 | g_loss: 0.4392
# Epoch [   44/   50] | d_loss: 0.3009 | g_loss: 0.6148
# Epoch [   44/   50] | d_loss: 0.2800 | g_loss: 0.4504
# Epoch [   45/   50] | d_loss: 0.2871 | g_loss: 0.3891
# Epoch [   45/   50] | d_loss: 0.2564 | g_loss: 0.6237
# Epoch [   45/   50] | d_loss: 0.3057 | g_loss: 0.5959
# Epoch [   45/   50] | d_loss: 0.2790 | g_loss: 0.5780
# Epoch [   45/   50] | d_loss: 0.2328 | g_loss: 0.7603
# Epoch [   45/   50] | d_loss: 0.2706 | g_loss: 0.4979
# Epoch [   45/   50] | d_loss: 0.3081 | g_loss: 0.7291
# Epoch [   45/   50] | d_loss: 0.2966 | g_loss: 0.6264
# Epoch [   45/   50] | d_loss: 0.2158 | g_loss: 0.7072
# Epoch [   45/   50] | d_loss: 0.2568 | g_loss: 0.7408
# Epoch [   45/   50] | d_loss: 0.3725 | g_loss: 0.7895
# Epoch [   45/   50] | d_loss: 0.3170 | g_loss: 0.3402
# Epoch [   45/   50] | d_loss: 0.2383 | g_loss: 0.6262
# Epoch [   45/   50] | d_loss: 0.2461 | g_loss: 0.5521
# Epoch [   45/   50] | d_loss: 0.3248 | g_loss: 0.3045
# Epoch [   46/   50] | d_loss: 0.2684 | g_loss: 0.3746
# Epoch [   46/   50] | d_loss: 0.3606 | g_loss: 0.7801
# Epoch [   46/   50] | d_loss: 0.2200 | g_loss: 0.5535
# Epoch [   46/   50] | d_loss: 0.4024 | g_loss: 0.8582
# Epoch [   46/   50] | d_loss: 0.3294 | g_loss: 0.3081
# Epoch [   46/   50] | d_loss: 0.4333 | g_loss: 0.9463
# Epoch [   46/   50] | d_loss: 0.5648 | g_loss: 0.3631
# Epoch [   46/   50] | d_loss: 0.2764 | g_loss: 0.4843
# Epoch [   46/   50] | d_loss: 0.2260 | g_loss: 0.6809
# Epoch [   46/   50] | d_loss: 0.3090 | g_loss: 0.6278
# Epoch [   46/   50] | d_loss: 0.2967 | g_loss: 0.6310
# Epoch [   46/   50] | d_loss: 0.5203 | g_loss: 0.1823
# Epoch [   46/   50] | d_loss: 0.3307 | g_loss: 0.6493
# Epoch [   46/   50] | d_loss: 0.2386 | g_loss: 0.4086
# Epoch [   46/   50] | d_loss: 0.3221 | g_loss: 0.3501
# Epoch [   47/   50] | d_loss: 0.1848 | g_loss: 0.5123
# Epoch [   47/   50] | d_loss: 0.3050 | g_loss: 0.6180
# Epoch [   47/   50] | d_loss: 0.2368 | g_loss: 0.5330
# Epoch [   47/   50] | d_loss: 0.4020 | g_loss: 0.2345
# Epoch [   47/   50] | d_loss: 0.2525 | g_loss: 0.3683
# Epoch [   47/   50] | d_loss: 0.2861 | g_loss: 0.5456
# Epoch [   47/   50] | d_loss: 0.3028 | g_loss: 0.8359
# Epoch [   47/   50] | d_loss: 0.2241 | g_loss: 0.8351
# Epoch [   47/   50] | d_loss: 0.2399 | g_loss: 0.4670
# Epoch [   47/   50] | d_loss: 0.2431 | g_loss: 0.4902
# Epoch [   47/   50] | d_loss: 0.2789 | g_loss: 0.4790
# Epoch [   47/   50] | d_loss: 0.2646 | g_loss: 0.8792
# Epoch [   47/   50] | d_loss: 0.2570 | g_loss: 0.5176
# Epoch [   47/   50] | d_loss: 0.3287 | g_loss: 0.4938
# Epoch [   47/   50] | d_loss: 0.3146 | g_loss: 0.2117
# Epoch [   48/   50] | d_loss: 0.2489 | g_loss: 0.2606
# Epoch [   48/   50] | d_loss: 0.2191 | g_loss: 0.8018
# Epoch [   48/   50] | d_loss: 0.2576 | g_loss: 0.4464
# Epoch [   48/   50] | d_loss: 0.1940 | g_loss: 0.9597
# Epoch [   48/   50] | d_loss: 0.3203 | g_loss: 0.2808
# Epoch [   48/   50] | d_loss: 0.2289 | g_loss: 0.6685
# Epoch [   48/   50] | d_loss: 0.3033 | g_loss: 1.3129
# Epoch [   48/   50] | d_loss: 0.2960 | g_loss: 0.4692
# Epoch [   48/   50] | d_loss: 0.3035 | g_loss: 0.6220
# Epoch [   48/   50] | d_loss: 0.2320 | g_loss: 0.6645
# Epoch [   48/   50] | d_loss: 0.2675 | g_loss: 0.6896
# Epoch [   48/   50] | d_loss: 0.1867 | g_loss: 0.5383
# Epoch [   48/   50] | d_loss: 0.2079 | g_loss: 0.7710
# Epoch [   48/   50] | d_loss: 0.2777 | g_loss: 0.4370
# Epoch [   48/   50] | d_loss: 0.2111 | g_loss: 0.4926
# Epoch [   49/   50] | d_loss: 0.2384 | g_loss: 0.5203
# Epoch [   49/   50] | d_loss: 0.2705 | g_loss: 0.6242
# Epoch [   49/   50] | d_loss: 0.6409 | g_loss: 0.1980
# Epoch [   49/   50] | d_loss: 0.2253 | g_loss: 0.4832
# Epoch [   49/   50] | d_loss: 0.2505 | g_loss: 0.6235
# Epoch [   49/   50] | d_loss: 0.2369 | g_loss: 0.7877
# Epoch [   49/   50] | d_loss: 0.2681 | g_loss: 0.6035
# Epoch [   49/   50] | d_loss: 0.2329 | g_loss: 0.4266
# Epoch [   49/   50] | d_loss: 0.2212 | g_loss: 0.4256
# Epoch [   49/   50] | d_loss: 0.2409 | g_loss: 0.5863
# Epoch [   49/   50] | d_loss: 0.2747 | g_loss: 0.4883
# Epoch [   49/   50] | d_loss: 0.2056 | g_loss: 0.4241
# Epoch [   49/   50] | d_loss: 0.3559 | g_loss: 0.8011
# Epoch [   49/   50] | d_loss: 0.2231 | g_loss: 0.7138
# Epoch [   49/   50] | d_loss: 0.1853 | g_loss: 0.6684
# Epoch [   50/   50] | d_loss: 0.2232 | g_loss: 0.5758
# Epoch [   50/   50] | d_loss: 0.2488 | g_loss: 0.7122
# Epoch [   50/   50] | d_loss: 0.2413 | g_loss: 0.5764
# Epoch [   50/   50] | d_loss: 0.2273 | g_loss: 0.7246
# Epoch [   50/   50] | d_loss: 0.3140 | g_loss: 0.3827
# Epoch [   50/   50] | d_loss: 0.2832 | g_loss: 0.6614
# Epoch [   50/   50] | d_loss: 0.3042 | g_loss: 0.5842
# Epoch [   50/   50] | d_loss: 0.3350 | g_loss: 0.9522
# Epoch [   50/   50] | d_loss: 0.2443 | g_loss: 0.4629
# Epoch [   50/   50] | d_loss: 0.3644 | g_loss: 0.5519
# Epoch [   50/   50] | d_loss: 0.2578 | g_loss: 0.4448
# Epoch [   50/   50] | d_loss: 0.2097 | g_loss: 0.7086
# Epoch [   50/   50] | d_loss: 0.1795 | g_loss: 0.5906
# Epoch [   50/   50] | d_loss: 0.2180 | g_loss: 0.6064
# Epoch [   50/   50] | d_loss: 0.2421 | g_loss: 0.6652

# %% [markdown]
# ## Training loss
#
# Plot the training losses for the generator and discriminator, recorded after each epoch.

# %%
fig, ax = plt.subplots()
losses = np.array(losses)
plt.plot(losses.T[0], label='Discriminator', alpha=0.5)
plt.plot(losses.T[1], label='Generator', alpha=0.5)
plt.title("Training Losses")
plt.legend()

# %% [markdown]
# ## Generator samples from training
#
# View samples of images from the generator, and answer a question about the strengths and weaknesses of your trained models.

# %%
# helper function for viewing a list of passed in sample images
def view_samples(epoch, samples):
    fig, axes = plt.subplots(figsize=(16,4), nrows=2, ncols=8, sharey=True, sharex=True)
    for ax, img in zip(axes.flatten(), samples[epoch]):
        img = img.detach().cpu().numpy()
        img = np.transpose(img, (1, 2, 0))
        img = ((img + 1)*255 / (2)).astype(np.uint8)
        ax.xaxis.set_visible(False)
        ax.yaxis.set_visible(False)
        im = ax.imshow(img.reshape((32,32,3)))

# %%
# Load samples from generator, taken while training
with open('train_samples.pkl', 'rb') as f:
    samples = pkl.load(f)

# %%
_ = view_samples(-1, samples)

# %% [markdown]
# ### Question: What do you notice about your generated samples and how might you improve this model?
# When you answer this question, consider the following factors:
# * The dataset is biased; it is made of "celebrity" faces that are mostly white
# * Model size; larger models have the opportunity to learn more features in a data feature space
# * Optimization strategy; optimizers and number of epochs affect your final result

# %% [markdown]
# **Answer:** As indicated above, the data is biased. Therefore, we only see white people faces. Some of generated samples are so realistic. In general, we need to tweak the parameters by changing hyperparameters. Another drawback is that original image size is so small like 64x64. if we had 2000x2000 image size, the results would be definitely better. There are many rooms to optimize the accuracy such as number of epochs, batch size, number of layers, learning rate and so on.

# %% [markdown]
# ### Submitting This Project
# When submitting this project, make sure to run all the cells before saving the notebook. Save the notebook file as "dlnd_face_generation.ipynb" and save it as a HTML file under "File" -> "Download as". Include the "problem_unittests.py" files in your submission.
